# %%
# 현재 Tensor 설치 여부 확인하기(tensorflow 1.15.0)

# !pip list
# Out:
# Package                            Version
# ---------------------------------- -------------------
# absl-py                            0.8.1
# alabaster                          0.7.12
# anaconda-client                    1.7.2
# anaconda-navigator                 1.9.7
# anaconda-project                   0.8.3
# argh                               0.26.2
# asn1crypto                         1.2.0
# astor                              0.8.1
# astroid                            2.3.3
# astropy                            3.0.2
# atomicwrites                       1.3.0
# attrs                              19.3.0
# autopep8                           1.4.4
# Babel                              2.7.0
# backcall                           0.1.0
# backports.os                       0.1.1
# backports.shutil-get-terminal-size 1.0.0
# bcrypt                             3.1.7
# beautifulsoup4                     4.8.1
# bitarray                           1.1.0
# ...

# %%
# cmd (관리자 계정으로 접속)
C:\WINDOWS\system32>activate root
(base) C:\WINDOWS\system32>pip install tensorflow==1.15.0

# %%
# !conda --version
# Out:
# conda 4.7.12

# %%
# 텐서플로 가능 파이썬 버전(3.5~3.7)
# !python --version
# Out:
# Python 3.6.9 :: Anaconda, Inc.

# %%
import sys
sys.version
# Out:
# '3.6.9 |Anaconda, Inc.| (default, Jul 30 2019, 14:00:49) [MSC v.1915 64 bit (AMD64)]'

# %%
pwd
# Out:
# 'C:\\JupyterSpace'

# %%
# Jupyter Notebook 실행하기

# Anaconda Prompt(Anaconda3) 선택(시작화면)
# C:\Users\choongang>cd\
# C:\>cd JupyterSpace
# C:\JupyterSpace> jupyter notebook

# %%
# test

import tensorflow as tf
hello=tf.constant('hello, java')
sess=tf.Session()
print(sess.run(hello))
# Out:
# b'hello, java'

# %%
# Theme
(base) C:\WINDOWS\system32>

# %%
# [잡동사니 명령어]
pip: 파이썬 설치 도움 패키지 (pip로 시작하는 명렁어들은 anaconda와 관련없음)
conda : 아나콘다   
[Tensorflow 설치하기]

Anaconda가 설치된 상태에서
cmd(관리자 명령)
C:\WINDOWS\system32>pip list
C:\WINDOWS\system32>conda update -n base conda
C:\WINDOWS\system32>conda update -all

[가상환경만들기]
C:\WINDOWS\system32>conda create -n envtensorflow pip python=3.6
C:\WINDOWS\system32>conda info --envs
[가상환경 활성화 하기]
C:\WINDOWS\system32>conda activate envtensorflow
[tensorflow 설치(최신]
C:\WINDOWS\system32>C:\WINDOWS\system32>conda install --ignore-installed --upgrade tensorflow
[tensorflow 설치(1.13.1)]
C:\WINDOWS\system32>C:\WINDOWS\system32>conda install tensorflow==1.13.1
(envtensorflow) C:\WINDOWS\system32>conda install tensorflow-gpu


[설치 확인]
(envTensflow)C:\WINDOWS\system32>python --version
(envTensflow)C:\WINDOWS\system32>python 
  (테스트 해보기~~~)

   import tensorflow as tf
   hello=tf.constant("Hello,Tensorflow")
   sess=tf.Session()
   print(sess.run(hello))

   exit()

[Jupyter notebook Kernel에 연결하기]
 (envTensflow)C:\WINDOWS\system32>conda install ipykernel
 (envTensflow)C:\WINDOWS\system32>
[python3가 직접 가상환경이 됨]      
 (envtensorflow) C:\WINDOWS\system32>python -m ipykernel install --name envtensorflow --display-name envtensorflow

[Jupyter Notebook안에서]
   import tensorflow as tf
   hello=tf.constant("Hello,Tensorflow")
   sess=tf.Session()
   print(sess.run(hello))

   아래와 같은 에러 발생: 
"ImportError: DLL load failed: 지정된 모듈을 찾을 수 없습니다."
==>방법
   (envtensorflow) C:\WINDOWS\system32>conda install tensorflow-gpu


pip uninstall tensorflow
pip install tensorflow==1.13.1
