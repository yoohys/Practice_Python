# %% [markdown]
# # KNN (K-Nearest_Neighbors: 최 근접)

# %% [markdown]
# ## Classifiaction : 예측하려는 대상의 속성을 입력받고, 종속 변수가 갖고있는 카테고리 (범주형)
# ### 값중에서 어느 한 분류로 예측한다.
# ### 지도학습(고객분류, 질병진단, 스팸메일 필터링, 음성인식)
# ### KNN, SVM, Decision Tree, Logistic Regression

# %%
from IPython.display import Image
Image("datasets/knn.png")

# %%
Image("datasets/classification.jpg")

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ## Step1 :: 데이터준비-Seaborn에서 제공하는 titanic 데이터셋 가져오기
